# %% [markdown]
# # Tag 2
#
# ## Funktionen

# %%
# Beispieltext von H-Soz-Kult

report = '''Die Editionswissenschaft erlebt nicht zuletzt wegen einer erfolgreichen Kombination von traditionellen Arbeitsweisen mit Methoden der Digital Humanities einen regelrechten Hype. Digitale Methoden drängen sich besonders an den Stellen auf, wo sie eine Überwindung der Beschränkungen des analogen Drucks versprechen. Zugleich zeichnet sich ab, dass mit einem Wechsel zu digitalen Editionsformen nicht nur neue Werkzeuge genutzt werden, sondern dass sich prinzipielle strukturelle Änderungen ergeben: so können analoge Editionen angereichert werden oder Editionen können als Hybrid durch eine gleichwertige digitale und analoge Version repräsentiert werden. Editoren werden angesichts dieser neuen Möglichkeiten vor neue Herausforderungen gestellt. Gleiches gilt für Infrastrukturen, die die Produkte der Editionswissenschaft publizieren und langfristig verfügbar machen sollen. Grundlegende Fragen der Qualitätsmessung und -bewertung, der Arbeitsorganisation, Vernetzung und Distribution müssen bei der digitalen Editionswissenschaft anders bzw. neu gestellt und bewertet werden. Die vom Forschungsverbund Marbach Weimar Wolfenbüttel veranstaltete Tagung “Digitale Metamorphose: Digital Humanities und Editionswissenschaft” betrachtete diese neuen Möglichkeiten kritisch und ging dabei auch der Frage nach, welche Grenzen und Gefahren es jenseits der offensichtlichen Vorteile für die Editionswissenschaft gibt. Den Auftakt der Tagung bildeten die Eröffnungsvorträge von BODO PLACHTA (Amsterdam) und JOÃO DIONÍSIO (Lissabon). Plachta wies auf die Bedeutung von philologischen Standards für die Editionsarbeit hin und stellte diese in ihrer historischen Entwicklung dar. Die aus dieser Entwicklung hervorgegangen editorischen Praktiken sollten auch im digitalen Medium gepflegt und weiterentwickelt werden. Die Vorteile des Digitalen dürfen nicht zu einem blinden Technikvertrauen führen, sondern müssen mit den traditionellen Qualitätsansprüchen der Editionswissenschaft kombiniert werden. Dionísio betonte die stetig wachsende Internationalität der Editionswissenschaft, die durch digitale Methoden und insbesondere durch neue Kommunikationsformen gefördert wird. Er beschrieb dabei die digitale Transformation der Editionswissenschaft in verschiedensten Bereichen wie dem Akt des Lesens, der institutionellen Kooperation, der Konstruktion und Interpretation von Textbedeutung und Textverstehen. Diesen Wandel skizzierte der Beiträger an den Beispielen der Archive und Gedächtnisinstitutionen sowie an den philologischen Netzwerken und wissenschaftlichen Verlagen. Austausch und Kooperationen werden in Zukunft gänzlich neue Editionsvorhaben ermöglichen und die Vernetzung über Sprach- und Landesgrenzen hinweg fördern. HEINZ-WERNER KRAMSKI (Marbach) eröffnete das erste Panel mit einem Beitrag über die Bestanderhaltung von digitalen Archivalien am Beispiel des Nachlasses des Literaturwissenschaftlers und Medientheoretikers Friedrich Kittler. Dabei verdeutlichte der Beiträger die vielfältigen Herausforderungen, die digitale Nachlässe über veraltete oder proprietäre Datei- und Textformate hinaus mit sich bringen. Gebrauchsspuren an Hardware, verschmutzte Datenträger oder selbst geschriebene Software der ehemaligen Anwender sind einige der sehr anschaulichen Fallbeispiele, die im Beitrag erwähnt wurden. SYBILLE SÖRING (Göttingen) stellte Textgrid und DARIAH als Infrastrukturen für digitale Editionen vor.[1] Textgrid stellt eine Arbeitsoberfläche für das – auch kollaborative – Auszeichnen von Text nach XML/TEI-P5 ebenso zur Verfügung als auch zahlreiche dabei unterstützende und analysierende Tools. DARIAH-DE unterstützt digital arbeitende Geistes- und Kulturwissenschaftler mit Digital-Humanities-Tools und fachwissenschaftlichen Diensten. Anhand des Editionsprojektes “Theodor Fontane: Notizbücher. Digitale genetisch-kritische und kommentierte Edition” erläutere die Referentin das Zusammenspiel der Infrastrukturen in den Bereichen der Erstellung, Präsentation und der nachhaltigen Verfügbarkeit.[2] PETER ANDORFER (Wien) erläuterte am Beispiel seines Editionsprojektes zur Weltbeschreibung des Tiroler Bauerns Leonhard Millinger die Vor- und Nachteile der Wolfenbütteler Digitalen Bibliothek (WDB) als Infrastruktur für die Erstellung einer digitalen Edition.[3] Die Rolle der Infrastruktur sieht Andorfer in einer generellen Unterstützung des Editionsvorhaben. Infrastrukturen können aber dem Editor nicht alle technischen und Kodierungsfragen und -entscheidungen abnehmen, eine “One-fits-all”-Lösung wird es alleine aufgrund der Spezifika von digitalen Editionen nicht geben können. Darüber hinaus betonte Andorfer, dass es für Editionen viel wichtiger sei, technische Ansprechpartner zu haben, die das Editionsvorhaben im Rahmen der gewählten Infrastruktur betreuen. Im ersten Teil seines Vortrages stellte ROLAND S. KAMZELAK (Marbach) die Hybrid-Edition der Tagebücher Harry Graf Kesslers vor. Ausgehend von der Edition wurde im zweiten Teil des Vortrags die interne Normdatenbank AMIE des Deutschen Literatur Archivs Marbach vorgestellt.[4] Die editionsübergreifende Datenbank ermöglicht es, direkt von den in ihr verzeichneten Registern in die Textstelle der jeweiligen Edition zu springen. Darüber hinaus verzeichnet die Datenbank die einzelnen Editionsrichtlinien. Der Vortrag zeigte überzeugend auf, wie arbeitserleichternd eine zentrale Datenhaltung und -pflege in Verbindung mit Normdaten für Editionsprojekte sein kann. In ihrem Beitrag stellte URSULA KUNDERT (Wolfenbüttel) anhand des Forschungsprojekts “Mediengeschichte der Psalmen” das Zusammenspiel von verschiedenen Infrastrukturen, zentralen Nachweissystemen und Social-Media-Angeboten dar. So entstand ein Abbild eines virtuellen Arbeitsplatzes, der sich auf verschiedene digitale Angebote erstreckt und das digitale Forschungsvorhaben mit dem Forschungsprofil des jeweiligen Forschers und dessen Einspeisung in fachspezifische Netzwerke unterstützt. Darüber hinaus wurde die Wichtigkeit einer intellektuellen Verbindung ausgehend von digitalen Editionen thematisiert. Nach dem ersten Panel fanden Kurzvorstellungen aktueller digitaler Editionsprojekte statt. HARTMUT BEYER (Wolfenbüttel) stellte die Edition des Tagebuches von Christian II. von Anhalt-Bernburg (1599–1656) vor. Die digitale Neuedition der deutschsprachigen Schwesternbücher des 14. Jahrhunderts wurde von CARINA HOFF (Trier) präsentiert. Danach stellten JULIA SCHMIDT-FUNKE und MARTIN PRELL (beide Jena) die digitale Edition der Briefe Erdmuthe Benignas von Reuß-Ebersdorf (1670–1732) vor. Das zweite Panel der Tagung eröffnete INGA HANNA RALLE (Wolfenbüttel) mit einem Vortrag, der einerseits das digitale Editionsvorhaben des Tagebuchs von Herzog August dem Jüngeren von Braunschweig-Wolfenbüttel und das damit in Verbindung stehende Selbstzeugnis-Repertorium der Herzog August Bibliothek vorstellte. Anderseits thematisierte der Vortrag die Bedeutung der Benutzbarkeit, Nutzerführung und Lesbarkeit von digitalen Editionen. Diese für die Nutzung von digitalen Editionen elementaren Faktoren werden noch nicht ausreichend bei der Editionserstellung berücksichtigt und stehen häufig hinter der Implementierung neuer technischer Methoden zurück. In dem nächsten Beitrag stellte ULRIKE HENNY (Köln) Reviewingverfahren für digitale Editionen vor. Dabei wurde die Rezensionszeitschrift RIDE vorgestellt und der von der Fachredaktion der Zeitschrift entwickelte Kriterienkatalog zur Besprechung von digitalen Editionen zur Diskussion gestellt.[5] Während Qualitätskriterien, die auch bei gedruckten Editionen angewendet werden, bei der Bewertung von digitalen Editionen adaptiert werden können, kommen zusätzlich noch weitere Faktoren hinzu, die vor allem aus dem Bereich der technischen Standards stammen. Zu Beginn des dritten Panels zeigte GEORG VOGELER (Graz) am Beispiel mittelalterlicher Rechnungsbücher das Potential der Digital Humanities und der sematischen Modellierung auf. Durch die Repräsentation von Text im Bild, durch das Mark-up von sprachlichen Informationen und die Auszeichnung von Bedeutung können unterschiedliche Zugänge zu editionskritischen Inhalten ermöglicht werden. Je nach wissenschaftlichem Blickwinkel schließen sich divergierende Ebenen somit nicht aus, sondern eröffnen neue Potenziale. Der Vortrag von JÖRG WETTLAUFER (Göttingen) ging auf die Möglichkeiten des Semantic Webs für die digitale Editionswissenschaft ein. Anhand zahlreicher Tools und Initiativen (LOD, RDF/SPARQL, Wikidata) zeigte er beispielsweise, wie eine automatische Generierung von Verknüpfungen aussehen kann, wo aber auch gleichzeitig Defizite der Qualitätssicherung und Herausforderungen liegen. Mit einem musikwissenschaftlichen Beitrag brachte JOACHIM VEIT (Paderborn) eine weitere fachliche Facette der digitalen Editionswissenschaft ein. Anhand von ausgewählten Beispielen wurde die Umsetzung von Musikeditionen demonstriert und auch die verschiedenen Entwicklungsschritte von ersten Prototypen bis zum aktuellen Stand aufgezeigt. Es stellte sich heraus, dass insbesondere das Feld der Musikeditionen, hier vor allem im Bereich der Visualisierung, von den Digital Humanities profitiert. GERRIT BRÜNING (Frankfurt am Main) diskutierte in seinem Beitrag das Verhältnis von Material und dessen digitaler Aufbereitung anhand der digitalen Faust-Edition.[6] Er thematisierte dabei das Verhältnis von analoger und digitaler Edition hinsichtlich Standards und kanonischer Vorbilder, die hier beispielsweise im Fall der “Weimarer Ausgabe” vorliegen. Es wurde deutlich, dass das Digitale hier Lösungen für die differenzierte Darstellung (Text-Genese vs. Dokument-Genese) bieten kann. Auch das dritte Panel schloss mit der Kurzvorstellung aktueller Editionsprojekte. BRITTA KLOSTERBERG (Halle) präsentierte die Aufbereitung der Tagebücher im Francke-Portal. CLAUDIA BAMBERG und JOCHEN STROBER (beide Marburg) zeigten den aktuellen Stand und Perspektiven bei der Briefedition A. W. Schlegels. Den Abschluss markierte die Präsentation von FRANZISKA DIEHR (Göttingen) zu einem Editionsprojekt, das Maya-Hieroglyphentexte digital aufbereitet. Die Tagungsteilnehmer waren sich darin einig, dass die Editionswissenschaft auf vielfache Weise von den Digital Humanities profitiert und sich durch die digitalen Methoden neue Editionsvorhaben eröffnen. Die Plenumsdiskussionen zwischen der Tagungsleitung und den Keynotespeakern machte aber auch deutlich, dass die grundsätzlichen, an digitale Editionsvorhaben zu stellenden Qualitätsansprüche sich an den traditionellen Standards orientieren müssen. Diese Kombination stellt die Editoren aber auch die Infrastruktureinrichtungen vor neue Herausforderungen. Dabei wurden insbesondere in den Bereichen der Qualitätsmessung, der Nachhaltigkeit, der Dissemination und der Visualisierung noch weiteres Potenzial für zukünftige Tagungen ausgemacht. Aber gerade diese Ergebnisse zeigen, dass es keine Trennung von analogen und digitalen Editoren geben darf, sondern dass die erfolgreiche Metamorphose der Editionswissenschaft in das digitale Zeitalter eine gemeinsame Aufgabe ist.'''


# Liste von Wörtern erzeugen
tokenized_report = report.split()

# %% [markdown]
# ### Absolute Häufigkeiten

# %%
def count_absolute_frequency(tokenized_text):
    """Parameter: list of strings
    The function returns a dictionary object containing the absolute frequency for
    each unique token in a given text."""

    # initialize empty dictionary
    frequencies = {}

    # compute absolute frequency
    for token in tokenized_text:
        if token in frequencies:
            frequencies[token] = frequencies[token] + 1
        else:
            frequencies[token] = 1
            
    return frequencies

# %%
# Aufruf der Funktionen
absolute_frequencies_report = count_absolute_frequency(tokenized_report)
print("Ergebnis der Berechnung der absoluten Häufigkeit:\n", absolute_frequencies_report, "\n")
# Out:
# Ergebnis der Berechnung der absoluten Häufigkeit:
#  {'Die': 9, 'Editionswissenschaft': 10, 'erlebt': 1, 'nicht': 7, 'zuletzt': 1, 'wegen': 1, 'einer': 4, 'erfolgreichen': 1, 'Kombination': 2, 'von': 36, 'traditionellen': 3, 'Arbeitsweisen': 1, 'mit': 10, 'Methoden': 5, 'der': 62, 'Digital': 5, 'Humanities': 5, 'einen': 1, 'regelrechten': 1, 'Hype.': 1, 'Digitale': 3, 'drängen': 1, 'sich': 10, 'besonders': 1, 'an': 6, 'den': 12, 'Stellen': 1, 'auf,': 2, 'wo': 2, 'sie': 1, 'eine': 8, 'Überwindung': 1, 'Beschränkungen': 1, 'des': 17, 'analogen': 2, 'Drucks': 1, 'versprechen.': 1, 'Zugleich': 1, 'zeichnet': 1, 'ab,': 1, 'dass': 9, 'einem': 6, 'Wechsel': 1, 'zu': 7, 'digitalen': 15, 'Editionsformen': 1, 'nur': 1, 'neue': 7, 'Werkzeuge': 1, 'genutzt': 1, 'werden,': 2, 'sondern': 4, 'prinzipielle': 1, 'strukturelle': 1, 'Änderungen': 1, 'ergeben:': 1, 'so': 1, 'können': 4, 'analoge': 2, 'Editionen': 11, 'angereichert': 1, 'werden': 5, 'oder': 3, 'als': 4, 'Hybrid': 1, 'durch': 5, 'gleichwertige': 1, 'digitale': 14, 'und': 53, 'Version': 1, 'repräsentiert': 1, 'werden.': 5, 'Editoren': 3, 'angesichts': 1, 'dieser': 2, 'neuen': 2, 'Möglichkeiten': 3, 'vor': 4, 'Herausforderungen': 2, 'gestellt.': 1, 'Gleiches': 1, 'gilt': 1, 'für': 13, 'Infrastrukturen,': 2, 'die': 47, 'Produkte': 1, 'publizieren': 1, 'langfristig': 1, 'verfügbar': 1, 'machen': 1, 'sollen.': 1, 'Grundlegende': 1, 'Fragen': 1, 'Qualitätsmessung': 1, '-bewertung,': 1, 'Arbeitsorganisation,': 1, 'Vernetzung': 2, 'Distribution': 1, 'müssen': 2, 'bei': 5, 'anders': 1, 'bzw.': 1, 'neu': 1, 'gestellt': 1, 'bewertet': 1, 'vom': 1, 'Forschungsverbund': 1, 'Marbach': 2, 'Weimar': 1, 'Wolfenbüttel': 1, 'veranstaltete': 1, 'Tagung': 3, '“Digitale': 1, 'Metamorphose:': 1, 'Editionswissenschaft”': 1, 'betrachtete': 1, 'diese': 3, 'kritisch': 1, 'ging': 2, 'dabei': 4, 'auch': 9, 'Frage': 1, 'nach,': 1, 'welche': 1, 'Grenzen': 1, 'Gefahren': 1, 'es': 4, 'jenseits': 1, 'offensichtlichen': 1, 'Vorteile': 2, 'gibt.': 1, 'Den': 2, 'Auftakt': 1, 'bildeten': 1, 'Eröffnungsvorträge': 1, 'BODO': 1, 'PLACHTA': 1, '(Amsterdam)': 1, 'JOÃO': 1, 'DIONÍSIO': 1, '(Lissabon).': 1, 'Plachta': 1, 'wies': 1, 'auf': 4, 'Bedeutung': 3, 'philologischen': 2, 'Standards': 4, 'Editionsarbeit': 1, 'hin': 1, 'stellte': 7, 'in': 13, 'ihrer': 1, 'historischen': 1, 'Entwicklung': 2, 'dar.': 2, 'aus': 2, 'hervorgegangen': 1, 'editorischen': 1, 'Praktiken': 1, 'sollten': 1, 'im': 8, 'Medium': 1, 'gepflegt': 1, 'weiterentwickelt': 1, 'Digitalen': 2, 'dürfen': 1, 'blinden': 1, 'Technikvertrauen': 1, 'führen,': 1, 'Qualitätsansprüchen': 1, 'kombiniert': 1, 'Dionísio': 1, 'betonte': 2, 'stetig': 1, 'wachsende': 1, 'Internationalität': 1, 'Editionswissenschaft,': 1, 'insbesondere': 3, 'Kommunikationsformen': 1, 'gefördert': 1, 'wird.': 1, 'Er': 2, 'beschrieb': 1, 'Transformation': 1, 'verschiedensten': 1, 'Bereichen': 3, 'wie': 3, 'dem': 7, 'Akt': 1, 'Lesens,': 1, 'institutionellen': 1, 'Kooperation,': 1, 'Konstruktion': 1, 'Interpretation': 1, 'Textbedeutung': 1, 'Textverstehen.': 1, 'Diesen': 1, 'Wandel': 1, 'skizzierte': 1, 'Beiträger': 2, 'Beispielen': 2, 'Archive': 1, 'Gedächtnisinstitutionen': 1, 'sowie': 1, 'Netzwerken': 1, 'wissenschaftlichen': 1, 'Verlagen.': 1, 'Austausch': 1, 'Kooperationen': 1, 'Zukunft': 1, 'gänzlich': 1, 'Editionsvorhaben': 5, 'ermöglichen': 1, 'über': 3, 'Sprach-': 1, 'Landesgrenzen': 1, 'hinweg': 1, 'fördern.': 1, 'HEINZ-WERNER': 1, 'KRAMSKI': 1, '(Marbach)': 2, 'eröffnete': 2, 'das': 17, 'erste': 1, 'Panel': 4, 'Beitrag': 6, 'Bestanderhaltung': 1, 'Archivalien': 1, 'am': 4, 'Beispiel': 3, 'Nachlasses': 1, 'Literaturwissenschaftlers': 1, 'Medientheoretikers': 1, 'Friedrich': 1, 'Kittler.': 1, 'Dabei': 3, 'verdeutlichte': 1, 'vielfältigen': 1, 'Herausforderungen,': 1, 'Nachlässe': 1, 'veraltete': 1, 'proprietäre': 1, 'Datei-': 1, 'Textformate': 1, 'hinaus': 4, 'bringen.': 1, 'Gebrauchsspuren': 1, 'Hardware,': 1, 'verschmutzte': 1, 'Datenträger': 1, 'selbst': 1, 'geschriebene': 1, 'Software': 1, 'ehemaligen': 1, 'Anwender': 1, 'sind': 1, 'e ...

# %% [markdown]
# ### Relative Häufigkeiten

# %%
def count_relative_frequency(frequency_dict, tokenized_text, multiplyer):
    """Parameters: dictionary object of absolute frequencies; list of strings;
    integer, which determines the value for calculating the relative frequency
    (e.g. 100 for percentage or 1000 for "per 1000 words") 
    The function returns a dictionary object containing the relative frequency for
    each unique token in a given text."""

    rel_frequency = {}

    # compute relative frequency
    for key in frequency_dict:
        rel_frequency[key] = (frequency_dict[key] / len(tokenized_text)) * multiplyer
    return rel_frequency

# %%
# Aufruf der Funktionen
relative_frequencies_report = count_relative_frequency(absolute_frequencies_report, tokenized_report, 100)
print("Ergebnis der Berechnung der relativen Häufigkeit (in diesem Fall Prozent):\n", relative_frequencies_report)
# Out:
# Ergebnis der Berechnung der relativen Häufigkeit (in diesem Fall Prozent):
#  {'Die': 0.6706408345752608, 'Editionswissenschaft': 0.7451564828614009, 'erlebt': 0.07451564828614009, 'nicht': 0.5216095380029807, 'zuletzt': 0.07451564828614009, 'wegen': 0.07451564828614009, 'einer': 0.29806259314456035, 'erfolgreichen': 0.07451564828614009, 'Kombination': 0.14903129657228018, 'von': 2.682563338301043, 'traditionellen': 0.22354694485842028, 'Arbeitsweisen': 0.07451564828614009, 'mit': 0.7451564828614009, 'Methoden': 0.37257824143070045, 'der': 4.619970193740686, 'Digital': 0.37257824143070045, 'Humanities': 0.37257824143070045, 'einen': 0.07451564828614009, 'regelrechten': 0.07451564828614009, 'Hype.': 0.07451564828614009, 'Digitale': 0.22354694485842028, 'drängen': 0.07451564828614009, 'sich': 0.7451564828614009, 'besonders': 0.07451564828614009, 'an': 0.44709388971684055, 'den': 0.8941877794336811, 'Stellen': 0.07451564828614009, 'auf,': 0.14903129657228018, 'wo': 0.14903129657228018, 'sie': 0.07451564828614009, 'eine': 0.5961251862891207, 'Überwindung': 0.07451564828614009, 'Beschränkungen': 0.07451564828614009, 'des': 1.2667660208643814, 'analogen': 0.14903129657228018, 'Drucks': 0.07451564828614009, 'versprechen.': 0.07451564828614009, 'Zugleich': 0.07451564828614009, 'zeichnet': 0.07451564828614009, 'ab,': 0.07451564828614009, 'dass': 0.6706408345752608, 'einem': 0.44709388971684055, 'Wechsel': 0.07451564828614009, 'zu': 0.5216095380029807, 'digitalen': 1.1177347242921014, 'Editionsformen': 0.07451564828614009, 'nur': 0.07451564828614009, 'neue': 0.5216095380029807, 'Werkzeuge': 0.07451564828614009, 'genutzt': 0.07451564828614009, 'werden,': 0.14903129657228018, 'sondern': 0.29806259314456035, 'prinzipielle': 0.07451564828614009, 'strukturelle': 0.07451564828614009, 'Änderungen': 0.07451564828614009, 'ergeben:': 0.07451564828614009, 'so': 0.07451564828614009, 'können': 0.29806259314456035, 'analoge': 0.14903129657228018, 'Editionen': 0.819672131147541, 'angereichert': 0.07451564828614009, 'werden': 0.37257824143070045, 'oder': 0.22354694485842028, 'als': 0.29806259314456035, 'Hybrid': 0.07451564828614009, 'durch': 0.37257824143070045, 'gleichwertige': 0.07451564828614009, 'digitale': 1.0432190760059614, 'und': 3.9493293591654246, 'Version': 0.07451564828614009, 'repräsentiert': 0.07451564828614009, 'werden.': 0.37257824143070045, 'Editoren': 0.22354694485842028, 'angesichts': 0.07451564828614009, 'dieser': 0.14903129657228018, 'neuen': 0.14903129657228018, 'Möglichkeiten': 0.22354694485842028, 'vor': 0.29806259314456035, 'Herausforderungen': 0.14903129657228018, 'gestellt.': 0.07451564828614009, 'Gleiches': 0.07451564828614009, 'gilt': 0.07451564828614009, 'für': 0.9687034277198211, 'Infrastrukturen,': 0.14903129657228018, 'die': 3.502235469448584, 'Produkte': 0.07451564828614009, 'publizieren': 0.07451564828614009, 'langfristig': 0.07451564828614009, 'verfügbar': 0.07451564828614009, 'machen': 0.07451564828614009, 'sollen.': 0.07451564828614009, 'Grundlegende': 0.07451564828614009, 'Fragen': 0.07451564828614009, 'Qualitätsmessung': 0.07451564828614009, '-bewertung,': 0.07451564828614009, 'Arbeitsorganisation,': 0.07451564828614009, 'Vernetzung': 0.14903129657228018, 'Distribution': 0.07451564828614009, 'müssen': 0.14903129657228018, 'bei': 0.37257824143070045, 'anders': 0.07451564828614009, 'bzw.': 0.07451564828614009, 'neu': 0.07451564828614009, 'gestellt': 0.07451564828614009, 'bewertet': 0.07451564828614009, 'vom': 0.07451564828614009, 'Forschungsverbund': 0.07451564828614009, 'Marbach': 0.14903129657228018, 'Weimar': 0.07451564828614009, 'Wolfenbüttel': 0.07451564828614009, 'veranstaltete': 0.07451564828614009, 'Tagung': 0.22354694485842028, '“Digitale': 0.07451564828614009, 'Metamorphose:': 0.07451564828614009, 'Editionswissenschaft”': 0.07451564828614009, 'betrachtete': 0.07451564828614009, 'diese': 0.22354694485842028, 'kritisch': 0.07451564828614009, 'ging': 0.14903129657228018, 'dabei': 0.29806259314456035, 'auch': 0.6706408345752608, 'Frage': 0.07451564828614009, 'nach,': 0.074515648286140 ...

# %% [markdown]
# ## Tokenisierung

# %%
def tokenize_text(text):
    
    # delete interpunction
    for each in '.,;"\'/\\!:?()[]':
        text = text.replace(each, '')

    # lower all characters        
    lowered_text = text.lower()
    
    # split text
    tokenized_text = lowered_text.split()
    
    return tokenized_text

# %%
report_tokens = tokenize_text(report)
report_tokens[:20]
# Out:
# ['die',
#  'editionswissenschaft',
#  'erlebt',
#  'nicht',
#  'zuletzt',
#  'wegen',
#  'einer',
#  'erfolgreichen',
#  'kombination',
#  'von',
#  'traditionellen',
#  'arbeitsweisen',
#  'mit',
#  'methoden',
#  'der',
#  'digital',
#  'humanities',
#  'einen',
#  'regelrechten',
#  'hype.']

# %%
absolute_frequencies_preprocessed = count_absolute_frequency(report_tokens)
print(absolute_frequencies_preprocessed)
# Out:
# {'die': 56, 'editionswissenschaft': 10, 'erlebt': 1, 'nicht': 7, 'zuletzt': 1, 'wegen': 1, 'einer': 4, 'erfolgreichen': 1, 'kombination': 2, 'von': 36, 'traditionellen': 3, 'arbeitsweisen': 1, 'mit': 11, 'methoden': 5, 'der': 64, 'digital': 7, 'humanities': 5, 'einen': 1, 'regelrechten': 1, 'hype.': 1, 'digitale': 17, 'drängen': 1, 'sich': 10, 'besonders': 1, 'an': 6, 'den': 14, 'stellen': 1, 'auf,': 2, 'wo': 2, 'sie': 1, 'eine': 8, 'überwindung': 1, 'beschränkungen': 1, 'des': 17, 'analogen': 2, 'drucks': 1, 'versprechen.': 1, 'zugleich': 1, 'zeichnet': 1, 'ab,': 1, 'dass': 9, 'einem': 6, 'wechsel': 1, 'zu': 8, 'digitalen': 17, 'editionsformen': 1, 'nur': 1, 'neue': 7, 'werkzeuge': 1, 'genutzt': 1, 'werden,': 2, 'sondern': 4, 'prinzipielle': 1, 'strukturelle': 1, 'änderungen': 1, 'ergeben:': 1, 'so': 2, 'können': 4, 'analoge': 2, 'editionen': 11, 'angereichert': 1, 'werden': 5, 'oder': 3, 'als': 4, 'hybrid': 1, 'durch': 6, 'gleichwertige': 1, 'und': 53, 'version': 1, 'repräsentiert': 1, 'werden.': 5, 'editoren': 3, 'angesichts': 1, 'dieser': 2, 'neuen': 2, 'möglichkeiten': 3, 'vor': 4, 'herausforderungen': 2, 'gestellt.': 1, 'gleiches': 1, 'gilt': 1, 'für': 13, 'infrastrukturen,': 2, 'produkte': 1, 'publizieren': 1, 'langfristig': 1, 'verfügbar': 1, 'machen': 1, 'sollen.': 1, 'grundlegende': 1, 'fragen': 1, 'qualitätsmessung': 1, '-bewertung,': 1, 'arbeitsorganisation,': 1, 'vernetzung': 2, 'distribution': 1, 'müssen': 2, 'bei': 5, 'anders': 1, 'bzw.': 1, 'neu': 1, 'gestellt': 1, 'bewertet': 1, 'vom': 1, 'forschungsverbund': 1, 'marbach': 2, 'weimar': 1, 'wolfenbüttel': 1, 'veranstaltete': 1, 'tagung': 3, '“digitale': 1, 'metamorphose:': 1, 'editionswissenschaft”': 1, 'betrachtete': 1, 'diese': 5, 'kritisch': 1, 'ging': 2, 'dabei': 7, 'auch': 10, 'frage': 1, 'nach,': 1, 'welche': 1, 'grenzen': 1, 'gefahren': 1, 'es': 6, 'jenseits': 1, 'offensichtlichen': 1, 'vorteile': 2, 'gibt.': 1, 'auftakt': 1, 'bildeten': 1, 'eröffnungsvorträge': 1, 'bodo': 1, 'plachta': 2, '(amsterdam)': 1, 'joão': 1, 'dionísio': 2, '(lissabon).': 1, 'wies': 1, 'auf': 4, 'bedeutung': 3, 'philologischen': 2, 'standards': 4, 'editionsarbeit': 1, 'hin': 1, 'stellte': 7, 'in': 15, 'ihrer': 1, 'historischen': 1, 'entwicklung': 2, 'dar.': 2, 'aus': 2, 'hervorgegangen': 1, 'editorischen': 1, 'praktiken': 1, 'sollten': 1, 'im': 9, 'medium': 1, 'gepflegt': 1, 'weiterentwickelt': 1, 'dürfen': 1, 'blinden': 1, 'technikvertrauen': 1, 'führen,': 1, 'qualitätsansprüchen': 1, 'kombiniert': 1, 'betonte': 2, 'stetig': 1, 'wachsende': 1, 'internationalität': 1, 'editionswissenschaft,': 1, 'insbesondere': 3, 'kommunikationsformen': 1, 'gefördert': 1, 'wird.': 1, 'er': 3, 'beschrieb': 1, 'transformation': 1, 'verschiedensten': 1, 'bereichen': 3, 'wie': 3, 'dem': 7, 'akt': 1, 'lesens,': 1, 'institutionellen': 1, 'kooperation,': 1, 'konstruktion': 1, 'interpretation': 1, 'textbedeutung': 1, 'textverstehen.': 1, 'diesen': 1, 'wandel': 1, 'skizzierte': 1, 'beiträger': 2, 'beispielen': 2, 'archive': 1, 'gedächtnisinstitutionen': 1, 'sowie': 1, 'netzwerken': 1, 'wissenschaftlichen': 1, 'verlagen.': 1, 'austausch': 1, 'kooperationen': 1, 'zukunft': 1, 'gänzlich': 1, 'editionsvorhaben': 5, 'ermöglichen': 1, 'über': 3, 'sprach-': 1, 'landesgrenzen': 1, 'hinweg': 1, 'fördern.': 1, 'heinz-werner': 1, 'kramski': 1, '(marbach)': 2, 'eröffnete': 2, 'das': 18, 'erste': 1, 'panel': 4, 'beitrag': 6, 'bestanderhaltung': 1, 'archivalien': 1, 'am': 4, 'beispiel': 3, 'nachlasses': 1, 'literaturwissenschaftlers': 1, 'medientheoretikers': 1, 'friedrich': 1, 'kittler.': 1, 'verdeutlichte': 1, 'vielfältigen': 1, 'herausforderungen,': 1, 'nachlässe': 1, 'veraltete': 1, 'proprietäre': 1, 'datei-': 1, 'textformate': 1, 'hinaus': 4, 'bringen.': 1, 'gebrauchsspuren': 1, 'hardware,': 1, 'verschmutzte': 1, 'datenträger': 1, 'selbst': 1, 'geschriebene': 1, 'software': 1, 'ehemaligen': 1, 'anwender': 1, 'sind': 1, 'einige': 1, 'sehr': 1, 'anschaulichen': 1, 'fallbeispiele,': 1, 'erwähnt': 1, 'wurden.': 1, ' ...

# %%
relative_frequencies_preprocessed = count_relative_frequency(absolute_frequencies_preprocessed, report_tokens, 100)
print(relative_frequencies_preprocessed)
# Out:
# {'die': 4.172876304023846, 'editionswissenschaft': 0.7451564828614009, 'erlebt': 0.07451564828614009, 'nicht': 0.5216095380029807, 'zuletzt': 0.07451564828614009, 'wegen': 0.07451564828614009, 'einer': 0.29806259314456035, 'erfolgreichen': 0.07451564828614009, 'kombination': 0.14903129657228018, 'von': 2.682563338301043, 'traditionellen': 0.22354694485842028, 'arbeitsweisen': 0.07451564828614009, 'mit': 0.819672131147541, 'methoden': 0.37257824143070045, 'der': 4.769001490312966, 'digital': 0.5216095380029807, 'humanities': 0.37257824143070045, 'einen': 0.07451564828614009, 'regelrechten': 0.07451564828614009, 'hype.': 0.07451564828614009, 'digitale': 1.2667660208643814, 'drängen': 0.07451564828614009, 'sich': 0.7451564828614009, 'besonders': 0.07451564828614009, 'an': 0.44709388971684055, 'den': 1.0432190760059614, 'stellen': 0.07451564828614009, 'auf,': 0.14903129657228018, 'wo': 0.14903129657228018, 'sie': 0.07451564828614009, 'eine': 0.5961251862891207, 'überwindung': 0.07451564828614009, 'beschränkungen': 0.07451564828614009, 'des': 1.2667660208643814, 'analogen': 0.14903129657228018, 'drucks': 0.07451564828614009, 'versprechen.': 0.07451564828614009, 'zugleich': 0.07451564828614009, 'zeichnet': 0.07451564828614009, 'ab,': 0.07451564828614009, 'dass': 0.6706408345752608, 'einem': 0.44709388971684055, 'wechsel': 0.07451564828614009, 'zu': 0.5961251862891207, 'digitalen': 1.2667660208643814, 'editionsformen': 0.07451564828614009, 'nur': 0.07451564828614009, 'neue': 0.5216095380029807, 'werkzeuge': 0.07451564828614009, 'genutzt': 0.07451564828614009, 'werden,': 0.14903129657228018, 'sondern': 0.29806259314456035, 'prinzipielle': 0.07451564828614009, 'strukturelle': 0.07451564828614009, 'änderungen': 0.07451564828614009, 'ergeben:': 0.07451564828614009, 'so': 0.14903129657228018, 'können': 0.29806259314456035, 'analoge': 0.14903129657228018, 'editionen': 0.819672131147541, 'angereichert': 0.07451564828614009, 'werden': 0.37257824143070045, 'oder': 0.22354694485842028, 'als': 0.29806259314456035, 'hybrid': 0.07451564828614009, 'durch': 0.44709388971684055, 'gleichwertige': 0.07451564828614009, 'und': 3.9493293591654246, 'version': 0.07451564828614009, 'repräsentiert': 0.07451564828614009, 'werden.': 0.37257824143070045, 'editoren': 0.22354694485842028, 'angesichts': 0.07451564828614009, 'dieser': 0.14903129657228018, 'neuen': 0.14903129657228018, 'möglichkeiten': 0.22354694485842028, 'vor': 0.29806259314456035, 'herausforderungen': 0.14903129657228018, 'gestellt.': 0.07451564828614009, 'gleiches': 0.07451564828614009, 'gilt': 0.07451564828614009, 'für': 0.9687034277198211, 'infrastrukturen,': 0.14903129657228018, 'produkte': 0.07451564828614009, 'publizieren': 0.07451564828614009, 'langfristig': 0.07451564828614009, 'verfügbar': 0.07451564828614009, 'machen': 0.07451564828614009, 'sollen.': 0.07451564828614009, 'grundlegende': 0.07451564828614009, 'fragen': 0.07451564828614009, 'qualitätsmessung': 0.07451564828614009, '-bewertung,': 0.07451564828614009, 'arbeitsorganisation,': 0.07451564828614009, 'vernetzung': 0.14903129657228018, 'distribution': 0.07451564828614009, 'müssen': 0.14903129657228018, 'bei': 0.37257824143070045, 'anders': 0.07451564828614009, 'bzw.': 0.07451564828614009, 'neu': 0.07451564828614009, 'gestellt': 0.07451564828614009, 'bewertet': 0.07451564828614009, 'vom': 0.07451564828614009, 'forschungsverbund': 0.07451564828614009, 'marbach': 0.14903129657228018, 'weimar': 0.07451564828614009, 'wolfenbüttel': 0.07451564828614009, 'veranstaltete': 0.07451564828614009, 'tagung': 0.22354694485842028, '“digitale': 0.07451564828614009, 'metamorphose:': 0.07451564828614009, 'editionswissenschaft”': 0.07451564828614009, 'betrachtete': 0.07451564828614009, 'diese': 0.37257824143070045, 'kritisch': 0.07451564828614009, 'ging': 0.14903129657228018, 'dabei': 0.5216095380029807, 'auch': 0.7451564828614009, 'frage': 0.07451564828614009, 'nach,': 0.07451564828614009, 'welche': 0.07451564828614009, 'grenzen': 0.0745156482861400 ...

# %% [markdown]
# ## Modulares Programmieren

# %%
from collections import Counter

# %%
counter = Counter(report_tokens)

# %%
counter
# Out:
# Counter({'die': 56,
#          'editionswissenschaft': 10,
#          'erlebt': 1,
#          'nicht': 7,
#          'zuletzt': 1,
#          'wegen': 1,
#          'einer': 4,
#          'erfolgreichen': 1,
#          'kombination': 2,
#          'von': 36,
#          'traditionellen': 3,
#          'arbeitsweisen': 1,
#          'mit': 11,
#          'methoden': 5,
#          'der': 64,
#          'digital': 7,
#          'humanities': 5,
#          'einen': 1,
#          'regelrechten': 1,
#          'hype.': 1,
#          'digitale': 17,
#          'drängen': 1,
#          'sich': 10,
#          'besonders': 1,
#          'an': 6,
#          'den': 14,
#          'stellen': 1,
#          'auf,': 2,
#          'wo': 2,
#          'sie': 1,
#          'eine': 8,
#          'überwindung': 1,
#          'beschränkungen': 1,
#          'des': 17,
#          'analogen': 2,
#          'drucks': 1,
#          'versprechen.': 1,
#          'zugleich': 1,
#          'zeichnet': 1,
#          'ab,': 1,
#          'dass': 9,
#          'einem': 6,
#          'wechsel': 1,
#          'zu': 8,
#          'digitalen': 17,
#          'editionsformen': 1,
#          'nur': 1,
#          'neue': 7,
#          'werkzeuge': 1,
#          'genutzt': 1,
#          'werden,': 2,
#          'sondern': 4,
#          'prinzipielle': 1,
#          'strukturelle': 1,
#          'änderungen': 1,
#          'ergeben:': 1,
#          'so': 2,
#          'können': 4,
#          'analoge': 2,
#          'editionen': 11,
#          'angereichert': 1,
#          'werden': 5,
#          'oder': 3,
#          'als': 4,
#          'hybrid': 1,
#          'durch': 6,
#          'gleichwertige': 1,
#          'und': 53,
#          'version': 1,
#          'repräsentiert': 1,
#          'werden.': 5,
#          'editoren': 3,
#          'angesichts': 1,
#          'dieser': 2,
#          'neuen': 2,
#          'möglichkeiten': 3,
#          'vor': 4,
#          'herausforderungen': 2,
#          'gestellt.': 1,
#          'gleiches': 1,
#          'gilt': 1,
#          'für': 13,
#          'infrastrukturen,': 2,
#          'produkte': 1,
#          'publizieren': 1,
#          'langfristig': 1,
#          'verfügbar': 1,
#          'machen': 1,
#          'sollen.': 1,
#          'grundlegende': 1,
#          'fragen': 1,
#          'qualitätsmessung': 1,
#          '-bewertung,': 1,
#          'arbeitsorganisation,': 1,
#          'vernetzung': 2,
#          'distribution': 1,
#          'müssen': 2,
#          'bei': 5,
#          'anders': 1,
#          'bzw.': 1,
#          'neu': 1,
#          'gestellt': 1,
#          'bewertet': 1,
#          'vom': 1,
#          'forschungsverbund': 1,
#          'marbach': 2,
#          'weimar': 1,
#          'wolfenbüttel': 1,
#          'veranstaltete': 1,
#          'tagung': 3,
#          '“digitale': 1,
#          'metamorphose:': 1,
#          'editionswissenschaft”': 1,
#          'betrachtete': 1,
#          'diese': 5,
#          'kritisch': 1,
#          'ging': 2,
#          'dabei': 7,
#          'auch': 10,
#          'frage': 1,
#          'nach,': 1,
#          'welche': 1,
#          'grenzen': 1,
#          'gefahren': 1,
#          'es': 6,
#          'jenseits': 1,
#          'offensichtlichen': 1,
#          'vorteile': 2,
#          'gibt.': 1,
#          'auftakt': 1,
#          'bildeten': 1,
#          'eröffnungsvorträge': 1,
#          'bodo': 1,
#          'plachta': 2,
#          '(amsterdam)': 1,
#          'joão': 1,
#          'dionísio': 2,
#          '(lissabon).': 1,
#          'wies': 1,
#          'auf': 4,
#          'bedeutung': 3,
#          'philologischen': 2,
#          'standards': 4,
#          'editionsarbeit': 1,
#          'hin': 1,
#          'stellte': 7,
#          'in': 15,
#          'ihrer': 1,
#          'historischen': 1,
#          'entwicklung': 2,
#          'dar.': 2,
#          'aus': 2,
#          'hervorgegangen': 1,
#          'editorischen': 1,
#          'praktiken': 1,
#          'sollten': 1,
#          'im': 9,
#          'medium': 1,
#          'gepflegt': 1,
#          'weiterentwickelt': 1,
#          'dürfen': 1,
#          'blinden': 1,
#          'technikvertrauen': 1,
#          'führen,': 1,
#          'qualitätsansprüchen': 1,
#          'kombiniert': 1,
#          'betonte': 2,
#          'stetig': 1,
#          'wachsende': 1,
#          'internationalität': 1,
#          'editionswissenschaft,': 1,
#          'insbesondere': 3,
#          'kommunikationsformen': 1,
#          'gefördert': 1,
#          'wird.': 1,
#          'er': 3,
#          'beschrieb': 1,
#          'transformation': 1,
#          'verschiedensten': 1,
#          'bereichen': 3,
#          'wie': 3,
#          'dem': 7,
#          'akt': 1,
#          'lesens,': 1,
#          'institutionellen': 1,
#          'kooperation,': 1,
#          'konstruktion': 1,
#          'interpretation': 1,
#          'textbedeutung': 1,
#          'textverstehen.': 1,
#          'diesen': 1,
#          'wandel': 1,
#          'skizzierte': 1,
#          'beiträger': 2,
#          'beispielen': 2,
#          'archive': 1,
#          'gedächtnisinstitutionen': 1,
#          'sowie': 1,
#          'netzwerken': 1,
#          'wissenschaftlichen': 1,
#          'verlagen.': 1,
#          'austausch': 1,
#          'kooperationen': 1,
#          'zukunft': 1,
#          'gänzlich': 1,
#          'editionsvorhaben': 5,
#          'ermöglichen': 1,
#          'über': 3,
#          'sprach-': 1,
#          'landesgrenzen': 1,
#          'hinweg': 1,
#          'fördern.': 1,
#          'heinz-werner': 1,
#          'kramski': 1,
#          '(marbach)': 2,
#          'eröffnete': 2,
#          'das': 18,
#          'erste': 1,
#          'panel': 4,
#          'beitrag': 6,
#          'bestanderhaltung': 1,
#          'archivalien': 1,
#          'am': 4,
#          'beispiel': 3,
#          'nachlasses': 1,
#          'literaturwissenschaftlers': 1,
#          'medientheoretikers': 1,
#          'friedrich': 1,
#          'kittler.': 1,
#          'verdeutlichte': 1,
#          'vielfältigen': 1,
#          'herausforderungen,': 1,
#          'nachlässe': 1,
#          'veraltete': 1,
#          'proprietäre': 1,
#          'datei-': 1,
#          'textformate': 1,
#          'hinaus': 4,
#          'bringen.': 1,
#          'gebrauchsspuren': 1,
#          'hardware,': 1,
#          'verschmutzte': 1,
#          'datenträger': 1,
#          'selbst': 1,
#          'geschriebene': 1,
#          'software': 1,
#          'ehemaligen': 1,
#          'anwender': 1,
#          'sind': 1,
#          'einige': 1,
#          'sehr': 1,
#          'anschaulichen': 1,
#          'fallbeispiele,': 1,
#          'erwähnt': 1,
#          'wurden.': 1,
#          'sybille': 1,
#          'söring': 1,
#          '(göttingen)': 3,
#          'textgrid': 2,
#          'dariah': 1,
#          'infrastrukturen': 3,
#          'vor.[1]': 1,
#          'stellt': 2,
#          'arbeitsoberfläche': 1,
#          '–': 2,
#          'kollaborative': 1,
#          'auszeichnen': 1,
#          'text': 2,
#          'nach': 3,
#          'xml/tei-p5': 1,
#          'ebenso': 1,
#          'zur': 4,
#          'verfügung': 1,
#          'zahlreiche': 1,
#          'unterstützende': 1,
#          'analysierende': 1,
#          'tools.': 1,
#          'dariah-de': 1,
#          'unterstützt': 1,
#          'arbeitende': 1,
#          'geistes-': 1,
#          'kulturwissenschaftler': 1,
#          'digital-humanities-tools': 1,
#          'fachwissenschaftlichen': 1,
#          'diensten.': 1,
#          'anhand': 5,
#          'editionsprojektes': 2,
#          '“theodor': 1,
#          'fontane:': 1,
#          'notizbücher.': 1,
#          'genetisch-kritische': 1,
#          'kommentierte': 1,
#          'edition”': 1,
#          'erläutere': 1,
#          'referentin': 1,
#          'zusammenspiel': 2,
#          'erstellung,': 1,
#          'präsentation': 2,
#          'nachhaltigen': 1,
#          'verfügbarkeit.[2]': 1,
#          'peter': 1,
#          'andorfer': 2,
#          '(wien)': 1,
#          'erläuterte': 1,
#          'seines': 2,
#          'weltbeschreibung': 1,
#          'tiroler': 1,
#          'bauerns': 1,
#          'leonhard': 1,
#          'millinger': 1,
#          'vor-': 1,
#          'nachteile': 1,
#          'wolfenbütteler': 1,
#          'bibliothek': 2,
#          '(wdb)': 1,
#          'infrastruktur': 3,
#          'erstellung': 1,
#          'edition.[3]': 1,
#          'rolle': 1,
#          'sieht': 1,
#          'generellen': 1,
#          'unterstützung': 1,
#          'editionsvorhaben.': 1,
#          'aber': 5,
#          'editor': 1,
#          'alle': 1,
#          'technischen': 2,
#          'kodierungsfragen': 1,
#          '-entscheidungen': 1,
#          'abnehmen,': 1,
#          '“one-fits-all”-lösung': 1,
#          'wird': 1,
#          'alleine': 1,
#          'aufgrund': 1,
#          'spezifika': 1,
#          'geben': 2,
#          'können.': 1,
#          'darüber': 3,
#          'andorfer,': 1,
#          'viel': 1,
#          'wichtiger': 1,
#          'sei,': 1,
#          'technische': 1,
#          'ansprechpartner': 1,
#          'haben,': 1,
#          'rahmen': 1,
#          'gewählten': 1,
#          'betreuen.': 1,
#          'ersten': 3,
#          'teil': 2,
#          'vortrages': 1,
#          'roland': 1,
#          's.': 1,
#          'kamzelak': 1,
#          'hybrid-edition': 1,
#          'tagebücher': 2,
#          'harry': 1,
#          'graf': 1,
#          'kesslers': 1,
#          'vor.': 4,
#          'ausgehend': 2,
#          'edition': 5,
#          'wurde': 6,
#          'zweiten': 1,
#          'vortrags': 1,
#          'interne': 1,
#          'normdatenbank': 1,
#          'amie': 1,
#          'deutschen': 1,
#          'literatur': 1,
#          'archivs': 1,
#          'vorgestellt.[4]': 1,
#          'editionsübergreifende': 1,
#          'datenbank': 2,
#          'ermöglicht': 2,
#          'es,': 1,
#          'direkt': 1,
#          'ihr': 1,
#          'verzeichneten': 1,
#          'registern': 1,
#          'textstelle': 1,
#          'jeweiligen': 2,
#          'springen.': 1,
#          'verzeichnet': 1,
#          'einzelnen': 1,
#          'editionsrichtlinien.': 1,
#          'vortrag': 3,
#          'zeigte': 3,
#          'überzeugend': 1,
#          'arbeitserleichternd': 1,
#          'zentrale': 1,
#          'datenhaltung': 1,
#          '-pflege': 1,
#          'verbindung': 3,
#          'normdaten': 1,
#          'editionsprojekte': 2,
#          'sein': 1,
#          'kann.': 2,
#          'ihrem': 1,
#          'ursula': 1,
#          'kundert': 1,
#          '(wolfenbüttel)': 3,
#          'forschungsprojekts': 1,
#          '“mediengeschichte': 1,
#          'psalmen”': 1,
#          'verschiedenen': 2,
#          'zentralen': 1,
#          'nachweissystemen': 1,
#          'social-media-angeboten': 1,
#          'entstand': 1,
#          'ein': 1,
#          'abbild': 1,
#          'eines': 1,
#          'virtuellen': 1,
#          'arbeitsplatzes,': 1,
#          'verschiedene': 1,
#          'angebote': 1,
#          'erstreckt': 1,
#          'forschungsvorhaben': 1,
#          'forschungsprofil': 1,
#          'forschers': 1,
#          'dessen': 2,
#          'einspeisung': 1,
#          'fachspezifische': 1,
#          'netzwerke': 1,
#          'unterstützt.': 1,
#          'wichtigkeit': 1,
#          'intellektuellen': 1,
#          'thematisiert.': 1,
#          'fanden': 1,
#          'kurzvorstellungen': 1,
#          'aktueller': 2,
#          'digitaler': 3,
#          'statt.': 1,
#          'hartmut': 1,
#          'beyer': 1,
#          'tagebuches': 1,
#          'christian': 1,
#          'ii.': 1,
#          'anhalt-bernburg': 1,
#          '(1599–1656)': 1,
#          'neuedition': 1,
#          'deutschsprachigen': 1,
#          'schwesternbücher': 1,
#          '14.': 1,
#          'jahrhunderts': 1,
#          'carina': 1,
#          'hoff': 1,
#          '(trier)': 1,
#          'präsentiert.': 1,
#          'danach': 1,
#          'stellten': 1,
#          'julia': 1,
#          'schmidt-funke': 1,
#          'martin': 1,
#          'prell': 1,
#          '(beide': 2,
#          'jena)': 1,
#          'briefe': 1,
#          'erdmuthe': 1,
#          'benignas': 1,
#          'reuß-ebersdorf': 1,
#          '(1670–1732)': 1,
#          'zweite': 1,
#          'inga': 1,
#          'hanna': 1,
#          'ralle': 1,
#          'vortrag,': 1,
#          'einerseits': 1,
#          'tagebuchs': 1,
#          'herzog': 2,
#          'august': 2,
#          'jüngeren': 1,
#          'braunschweig-wolfenbüttel': 1,
#          'damit': 1,
#          'stehende': 1,
#          'selbstzeugnis-repertorium': 1,
#          'vorstellte.': 1,
#          'anderseits': 1,
#          'thematisierte': 2,
#          'benutzbarkeit,': 1,
#          'nutzerführung': 1,
#          'lesbarkeit': 1,
#          'editionen.': 1,
#          'nutzung': 1,
#          'elementaren': 1,
#          'faktoren': 2,
#          'noch': 3,
#          'ausreichend': 1,
#          'editionserstellung': 1,
#          'berücksichtigt': 1,
#          'stehen': 1,
#          'häufig': 1,
#          'hinter': 1,
#          'implementierung': 1,
#          'neuer': 1,
#          'technischer': 1,
#          'zurück.': 1,
#          'nächsten': 1,
#          'ulrike': 1,
#          'henny': 1,
#          '(köln)': 1,
#          'reviewingverfahren': 1,
#          'rezensionszeitschrift': 1,
#          'ride': 1,
#          'vorgestellt': 1,
#          'fachredaktion': 1,
#          'zeitschrift': 1,
#          'entwickelte': 1,
#          'kriterienkatalog': 1,
#          'besprechung': 1,
#          'diskussion': 1,
#          'gestellt.[5]': 1,
#          'während': 1,
#          'qualitätskriterien,': 1,
#          'gedruckten': 1,
#          'angewendet': 1,
#          'bewertung': 1,
#          'adaptiert': 1,
#          'können,': 1,
#          'kommen': 1,
#          'zusätzlich': 1,
#          'weitere': 2,
#          'hinzu,': 1,
#          'allem': 2,
#          'bereich': 2,
#          'stammen.': 1,
#          'beginn': 1,
#          'dritten': 1,
#          'panels': 1,
#          'georg': 1,
#          'vogeler': 1,
#          '(graz)': 1,
#          'mittelalterlicher': 1,
#          'rechnungsbücher': 1,
#          'potential': 1,
#          'sematischen': 1,
#          'modellierung': 1,
#          'auf.': 1,
#          'repräsentation': 1,
#          'bild,': 1,
#          'mark-up': 1,
#          'sprachlichen': 1,
#          'informationen': 1,
#          'auszeichnung': 1,
#          'unterschiedliche': 1,
#          'zugänge': 1,
#          'editionskritischen': 1,
#          'inhalten': 1,
#          'je': 1,
#          'wissenschaftlichem': 1,
#          'blickwinkel': 1,
#          'schließen': 1,
#          'divergierende': 1,
#          'ebenen': 1,
#          'somit': 1,
#          'aus,': 1,
#          'eröffnen': 1,
#          'potenziale.': 1,
#          'jörg': 1,
#          'wettlaufer': 1,
#          'semantic': 1,
#          'webs': 1,
#          'ein.': 2,
#          'zahlreicher': 1,
#          'tools': 1,
#          'initiativen': 1,
#          '(lod,': 1,
#          'rdf/sparql,': 1,
#          'wikidata)': 1,
#          'beispielsweise,': 1,
#          'automatische': 1,
#          'generierung': 1,
#          'verknüpfungen': 1,
#          'aussehen': 1,
#          'kann,': 1,
#          'gleichzeitig': 1,
#          'defizite': 1,
#          'qualitätssicherung': 1,
#          'liegen.': 1,
#          'musikwissenschaftlichen': 1,
#          'brachte': 1,
#          'joachim': 1,
#          'veit': 1,
#          '(paderborn)': 1,
#          'fachliche': 1,
#          'facette': 1,
#          'ausgewählten': 1,
#          'umsetzung': 1,
#          'musikeditionen': 1,
#          'demonstriert': 1,
#          'entwicklungsschritte': 1,
#          'prototypen': 1,
#          'bis': 1,
#          'zum': 1,
#          'aktuellen': 2,
#          'stand': 2,
#          'aufgezeigt.': 1,
#          'heraus,': 1,
#          'feld': 1,
#          'musikeditionen,': 1,
#          'hier': 3,
#          'visualisierung,': 1,
#          'profitiert.': 1,
#          'gerrit': 1,
#          'brüning': 1,
#          '(frankfurt': 1,
#          'main)': 1,
#          'diskutierte': 1,
#          'seinem': 1,
#          'verhältnis': 2,
#          'material': 1,
#          'aufbereitung': 2,
#          'faust-edition.[6]': 1,
#          'analoger': 1,
#          'hinsichtlich': 1,
#          'kanonischer': 1,
#          'vorbilder,': 1,
#          'beispielsweise': 1,
#          'fall': 1,
#          '“weimarer': 1,
#          'ausgabe”': 1,
#          'vorliegen.': 1,
#          'deutlich,': 2,
#          'lösungen': 1,
#          'differenzierte': 1,
#          'darstellung': 1,
#          '(text-genese': 1,
#          'vs.': 1,
#          'dokument-genese)': 1,
#          'bieten': 1,
#          'dritte': 1,
#          'schloss': 1,
#          'kurzvorstellung': 1,
#          'editionsprojekte.': 1,
#          'britta': 1,
#          'klosterberg': 1,
#          '(halle)': 1,
#          'präsentierte': 1,
#          'francke-portal.': 1,
#          'claudia': 1,
#          'bamberg': 1,
#          'jochen': 1,
#          'strober': 1,
#          'marburg)': 1,
#          'zeigten': 1,
#          'perspektiven': 1,
#          'briefedition': 1,
#          'a.': 1,
#          'w.': 1,
#          'schlegels.': 1,
#          'abschluss': 1,
#          'markierte': 1,
#          'franziska': 1,
#          'diehr': 1,
#          'editionsprojekt,': 1,
#          'maya-hieroglyphentexte': 1,
#          'aufbereitet.': 1,
#          'tagungsteilnehmer': 1,
#          'waren': 1,
#          'darin': 1,
#          'einig,': 1,
#          'vielfache': 1,
#          'weise': 1,
#          'profitiert': 1,
#          'eröffnen.': 1,
#          'plenumsdiskussionen': 1,
#          'zwischen': 1,
#          'tagungsleitung': 1,
#          'keynotespeakern': 1,
#          'machte': 1,
#          'grundsätzlichen,': 1,
#          'stellenden': 1,
#          'qualitätsansprüche': 1,
#          'orientieren': 1,
#          'müssen.': 1,
#          'infrastruktureinrichtungen': 1,
#          'herausforderungen.': 1,
#          'wurden': 1,
#          'qualitätsmessung,': 1,
#          'nachhaltigkeit,': 1,
#          'dissemination': 1,
#          'visualisierung': 1,
#          'weiteres': 1,
#          'potenzial': 1,
#          'zukünftige': 1,
#          'tagungen': 1,
#          'ausgemacht.': 1,
#          'gerade': 1,
#          'ergebnisse': 1,
#          'zeigen,': 1,
#          'keine': 1,
#          'trennung': 1,
#          'darf,': 1,
#          'erfolgreiche': 1,
#          'metamorphose': 1,
#          'zeitalter': 1,
#          'gemeinsame': 1,
#          'aufgabe': 1,
#          'ist.': 1})

# %%
top_words = counter.most_common(25)

# %%
top_words
# Out:
# [('der', 64),
#  ('die', 56),
#  ('und', 53),
#  ('von', 36),
#  ('das', 18),
#  ('digitale', 17),
#  ('des', 17),
#  ('digitalen', 17),
#  ('in', 15),
#  ('den', 14),
#  ('für', 13),
#  ('mit', 11),
#  ('editionen', 11),
#  ('editionswissenschaft', 10),
#  ('sich', 10),
#  ('auch', 10),
#  ('dass', 9),
#  ('im', 9),
#  ('eine', 8),
#  ('zu', 8),
#  ('nicht', 7),
#  ('digital', 7),
#  ('neue', 7),
#  ('dabei', 7),
#  ('stellte', 7)]

# %% [markdown]
# ## Visualisieren

# %%
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
y = [count for word, count in top_words]
x = [word for word, count in top_words]

plt.figure(figsize=(12, 8))

plt.bar(x, y)
plt.title('Worthäufigkeiten', fontsize=22, fontstyle='oblique')
plt.xlabel('Top Words', fontsize=20)
plt.ylabel('Absolute Häufigkeiten', fontsize=20)
plt.xticks(fontsize=15, rotation=85)
plt.tight_layout() # for optimal fit
#plt.savefig("PATH") # save figure to disk
plt.show()

# %%
y = [count for word, count in top_words]
x = [word for word, count in top_words]

fig, ax = plt.subplots(figsize=(10, 10))

ax.barh(x, y)
ax.set_title('Worthäufigkeiten der Top Words', fontsize=22, fontstyle='oblique')
ax.set_xlabel('Häufigkeiten', fontsize=20)
ax.set_ylabel('Top Words', fontsize=20)
ax.invert_yaxis();

# %% [markdown]
# ## Wordcloud

# %%
from wordcloud import WordCloud

# %%
wc = WordCloud(width=3000, height=2000,
        random_state=42,
        background_color='white',
        colormap='magma',
       # stopwords=stop_words,
        collocations=False,  # Bigrams werden dargestellt
        collocation_threshold=8,
        max_words=100)
        
wc.generate(report)

plt.figure(figsize=(15, 15))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.title('Wordcloud', fontsize=16, weight='semibold');
